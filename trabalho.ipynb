# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.3.0)
# Requirement already satisfied: py4j==0.10.9.5 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.5)

# %%
# rodar o google drive no colab, puxa todo conteúdo do drive da pessoa
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("TrabalhoPratico").getOrCreate()

title_basics = spark.read \
    .format('csv') \
    .option("sep", "	") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/content/drive/MyDrive/MBA-mod2/title_basics.tsv")

title_basics.show(20)
# Out:
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+
# |   tconst|titleType|        primaryTitle|       originalTitle|isAdult|startYear|endYear|runtimeMinutes|              genres|
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+
# |tt0000001|    short|          Carmencita|          Carmencita|      0|     1894|     \N|             1|   Documentary,Short|
# |tt0000002|    short|Le clown et ses c...|Le clown et ses c...|      0|     1892|     \N|             5|     Animation,Short|
# |tt0000003|    short|      Pauvre Pierrot|      Pauvre Pierrot|      0|     1892|     \N|             4|Animation,Comedy,...|
# |tt0000004|    short|         Un bon bock|         Un bon bock|      0|     1892|     \N|            12|     Animation,Short|
# |tt0000005|    short|    Blacksmith Scene|    Blacksmith Scene|      0|     1893|     \N|             1|        Comedy,Short|
# |tt0000006|    short|   Chinese Opium Den|   Chinese Opium Den|      0|     1894|     \N|             1|               Short|
# |tt0000007|    short|Corbett and Court...|Corbett and Court...|      0|     1894|     \N|             1|         Short,Sport|
# |tt0000008|    short|Edison Kinetoscop...|Edison Kinetoscop...|      0|     1894|     \N|             1|   Documentary,Short|
# |tt0000009|    short|          Miss Jerry|          Miss Jerry|      0|     1894|     \N|            40|       Romance,Short|
# |tt0000010|    short| Leaving the Factory|La sortie de l'us...|      0|     1895|     \N|             1|   Documentary,Short|
# |tt0000011|    short|Akrobatisches Pot...|Akrobatisches Pot...|      0|     1895|     \N|             1|   Documentary,Short|
# |tt0000012|    short|The Arrival of a ...|L'arrivée d'un tr...|      0|     1896|     \N|             1|   Documentary,Short|
# |tt0000013|    short|The Photographica...|Le débarquement d...|      0|     1895|     \N|             1|   Documentary,Short|
# |tt0000014|    short| The Waterer Watered|   L'arroseur arrosé|      0|     1895|     \N|             1|        Comedy,Short|
# |tt0000015|    short| Autour d'une cabine| Autour d'une cabine|      0|     1894|     \N|             2|     Animation,Short|
# |tt0000016|    short|Boat Leaving the ...|Barque sortant du...|      0|     1895|     \N|             1|   Documentary,Short|
# |tt0000017|    short|Italienischer Bau...|Italienischer Bau...|      0|     1895|     \N|             1|   Documentary,Short|
# |tt0000018|    short|Das boxende Känguruh|Das boxende Känguruh|      0|     1895|     \N|             1|               Short|
# |tt0000019|    short|    The Clown Barber|    The Clown Barber|      0|     1898|     \N|            \N|        Comedy,Short|
# |tt0000020|    short|      The Derby 1895|      The Derby 1895|      0|     1895|     \N|             1|Documentary,Short...|
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+
# only showing top 20 rows

# %%
title_basics.printSchema()
# Out:
# root
#  |-- tconst: string (nullable = true)
#  |-- titleType: string (nullable = true)
#  |-- primaryTitle: string (nullable = true)
#  |-- originalTitle: string (nullable = true)
#  |-- isAdult: string (nullable = true)
#  |-- startYear: string (nullable = true)
#  |-- endYear: string (nullable = true)
#  |-- runtimeMinutes: string (nullable = true)
#  |-- genres: string (nullable = true)

# %%
title_ratings = spark.read \
    .format('csv') \
    .option("sep", "	") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/content/drive/MyDrive/MBA-mod2/title_ratings.tsv")

title_ratings.show(20)
# Out:
# +---------+-------------+--------+
# |   tconst|averageRating|numVotes|
# +---------+-------------+--------+
# |tt0000001|          5.7|    1809|
# |tt0000002|          6.0|     233|
# |tt0000003|          6.5|    1560|
# |tt0000004|          6.1|     152|
# |tt0000005|          6.2|    2383|
# |tt0000006|          5.1|     157|
# |tt0000007|          5.4|     746|
# |tt0000008|          5.5|    1965|
# |tt0000009|          5.8|     189|
# |tt0000010|          6.9|    6530|
# |tt0000011|          5.2|     323|
# |tt0000012|          7.4|   11188|
# |tt0000013|          5.8|    1726|
# |tt0000014|          7.1|    5023|
# |tt0000015|          6.2|     947|
# |tt0000016|          5.9|    1325|
# |tt0000017|          4.6|     292|
# |tt0000018|          5.3|     537|
# |tt0000019|          5.3|      28|
# |tt0000020|          5.0|     315|
# +---------+-------------+--------+
# only showing top 20 rows

# %%
title_ratings.printSchema()
# Out:
# root
#  |-- tconst: string (nullable = true)
#  |-- averageRating: double (nullable = true)
#  |-- numVotes: integer (nullable = true)

# %%
title_basics.groupBy("titleType").count().toPandas()
# Out:
#        titleType    count
# 0       tvSeries   213405
# 1   tvMiniSeries    39133
# 2        tvMovie   132690
# 3      tvEpisode  6012696
# 4          movie   585950
# 5      tvSpecial    33896
# 6          video   319124
# 7      videoGame    28962
# 8        tvShort    10236
# 9          short   827595
# 10       tvPilot        1
# 11   radioSeries        1
# 12  radioEpisode        1

# %%
title_basics.filter("startYear == '2015' and titleType in ('tvMovie', 'movie')").count()
# Out:
# 19987

# %%
import pyspark.sql.functions as f

# %%
title_array = title_basics.withColumn('genres_array', f.split(f.col('genres'), ','))
title_array.show(5)
# Out:
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+--------------------+
# |   tconst|titleType|        primaryTitle|       originalTitle|isAdult|startYear|endYear|runtimeMinutes|              genres|        genres_array|
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+--------------------+
# |tt0000001|    short|          Carmencita|          Carmencita|      0|     1894|     \N|             1|   Documentary,Short|[Documentary, Short]|
# |tt0000002|    short|Le clown et ses c...|Le clown et ses c...|      0|     1892|     \N|             5|     Animation,Short|  [Animation, Short]|
# |tt0000003|    short|      Pauvre Pierrot|      Pauvre Pierrot|      0|     1892|     \N|             4|Animation,Comedy,...|[Animation, Comed...|
# |tt0000004|    short|         Un bon bock|         Un bon bock|      0|     1892|     \N|            12|     Animation,Short|  [Animation, Short]|
# |tt0000005|    short|    Blacksmith Scene|    Blacksmith Scene|      0|     1893|     \N|             1|        Comedy,Short|     [Comedy, Short]|
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+--------------------+
# only showing top 5 rows

# %%
title_exp = title_array.withColumn('genres_unico', f.explode(f.col('genres_array')))
title_exp.show(5)
# Out:
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+--------------------+------------+
# |   tconst|titleType|        primaryTitle|       originalTitle|isAdult|startYear|endYear|runtimeMinutes|              genres|        genres_array|genres_unico|
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+--------------------+------------+
# |tt0000001|    short|          Carmencita|          Carmencita|      0|     1894|     \N|             1|   Documentary,Short|[Documentary, Short]| Documentary|
# |tt0000001|    short|          Carmencita|          Carmencita|      0|     1894|     \N|             1|   Documentary,Short|[Documentary, Short]|       Short|
# |tt0000002|    short|Le clown et ses c...|Le clown et ses c...|      0|     1892|     \N|             5|     Animation,Short|  [Animation, Short]|   Animation|
# |tt0000002|    short|Le clown et ses c...|Le clown et ses c...|      0|     1892|     \N|             5|     Animation,Short|  [Animation, Short]|       Short|
# |tt0000003|    short|      Pauvre Pierrot|      Pauvre Pierrot|      0|     1892|     \N|             4|Animation,Comedy,...|[Animation, Comed...|   Animation|
# +---------+---------+--------------------+--------------------+-------+---------+-------+--------------+--------------------+--------------------+------------+
# only showing top 5 rows

# %%
title_exp.groupBy("genres_array").count().orderBy("count").toPandas()
# Out:
#                 genres_array   count
# 0        [Film-Noir, Horror]       2
# 1     [Adventure, Film-Noir]       2
# 2           [Musical, Sport]       2
# 3           [Talk-Show, War]       2
# 4            [News, Romance]       2
# ...                      ...     ...
# 2285             [Talk-Show]  467788
# 2286                [Comedy]  568956
# 2287                    [\N]  643012
# 2288        [Drama, Romance]  709470
# 2289                 [Drama]  880649
#
# [2290 rows x 2 columns]

# %%
df_left = title_ratings.join(title_exp, "tconst", "left")

df_left.show(5)
# Out:
# +---------+-------------+--------+---------+--------------------+--------------------+-------+---------+-------+--------------+-----------------+--------------------+------------+
# |   tconst|averageRating|numVotes|titleType|        primaryTitle|       originalTitle|isAdult|startYear|endYear|runtimeMinutes|           genres|        genres_array|genres_unico|
# +---------+-------------+--------+---------+--------------------+--------------------+-------+---------+-------+--------------+-----------------+--------------------+------------+
# |tt1790891|          6.5|       6|    short|The Cameras of Va...|Vaalan kamerat py...|      0|     1937|     \N|             8|Documentary,Short|[Documentary, Short]| Documentary|
# |tt1790891|          6.5|       6|    short|The Cameras of Va...|Vaalan kamerat py...|      0|     1937|     \N|             8|Documentary,Short|[Documentary, Short]|       Short|
# |tt0000002|          6.0|     233|    short|Le clown et ses c...|Le clown et ses c...|      0|     1892|     \N|             5|  Animation,Short|  [Animation, Short]|   Animation|
# |tt0000002|          6.0|     233|    short|Le clown et ses c...|Le clown et ses c...|      0|     1892|     \N|             5|  Animation,Short|  [Animation, Short]|       Short|
# |tt0000004|          6.1|     152|    short|         Un bon bock|         Un bon bock|      0|     1892|     \N|            12|  Animation,Short|  [Animation, Short]|   Animation|
# +---------+-------------+--------+---------+--------------------+--------------------+-------+---------+-------+--------------+-----------------+--------------------+------------+
# only showing top 5 rows

# %%
df_left.agg(f.max("averageRating").alias('nota_maxima')).show(20)
# Out:
# +-----------+
# |nota_maxima|
# +-----------+
# |       10.0|
# +-----------+

# %%
df_left.filter("averageRating == '10'").groupBy("genres_unico").count().toPandas()
# Out:
#    genres_unico  count
# 0         Crime     92
# 1       Romance    176
# 2      Thriller     29
# 3     Adventure    382
# 4            \N     53
# 5         Drama   2099
# 6           War      3
# 7   Documentary    383
# 8    Reality-TV    133
# 9        Family    297
# 10      Fantasy     41
# 11    Game-Show     55
# 12        Adult     33
# 13      History     28
# 14      Mystery    105
# 15      Musical     54
# 16    Animation     42
# 17        Music    371
# 18        Short    569
# 19       Horror     10
# 20    Biography     61
# 21       Comedy   1066
# 22       Action    368
# 23        Sport     64
# 24    Talk-Show    367
# 25       Sci-Fi      9
# 26         News     30

# %%
df_left.filter("titleType == 'videoGame' and startYear=='2020' and averageRating >= '9.5'").toPandas()
# Out:
#        tconst  averageRating  numVotes  titleType     primaryTitle  \
# 0  tt11321196            9.5       506  videoGame  Half-Life: Alyx
# 1  tt11321196            9.5       506  videoGame  Half-Life: Alyx
# 2  tt11321196            9.5       506  videoGame  Half-Life: Alyx
#
#      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0  Half-Life: Alyx       0      2020      \N             \N
# 1  Half-Life: Alyx       0      2020      \N             \N
# 2  Half-Life: Alyx       0      2020      \N             \N
#
#                     genres                 genres_array genres_unico
# 0  Action,Adventure,Horror  [Action, Adventure, Horror]       Action
# 1  Action,Adventure,Horror  [Action, Adventure, Horror]    Adventure
# 2  Action,Adventure,Horror  [Action, Adventure, Horror]       Horror

# %%
from pyspark.sql.window import Window

# %%
df_titles_subset = (
    df_left
    .filter("cast(startYear as int) == 2018")
    .withColumn('genre', f.split('genres', ',').getItem(0))
)

# %%
df_titles_subset.count()
# Out:
# 107080

# %%
df_titles_subset.withColumn('genre', f.split('genres', ',').getItem(0)).limit(5).toPandas()
# Out:
#       tconst  averageRating  numVotes titleType  \
# 0  tt0137818            4.4        31     movie
# 1  tt0170651            6.8        14     movie
# 2  tt0271577            5.0         6     short
# 3  tt0328810            7.6        85     movie
# 4  tt0328810            7.6        85     movie
#
#                                         primaryTitle  \
# 0  Housesitter: The Night They Saved Siegfried's ...
# 1                                  TGM the Liberator
# 2                               Je suis votre voisin
# 3                                            My Land
# 4                                            My Land
#
#                                        originalTitle isAdult startYear  \
# 0  Housesitter: The Night They Saved Siegfried's ...       0      2018
# 1                               T.G.M. - osvoboditel       0      2018
# 2                               Je suis votre voisin       0      2018
# 3                                      Aamaar Bhuvan       0      2018
# 4                                      Aamaar Bhuvan       0      2018
#
#   endYear runtimeMinutes        genres     genres_array genres_unico  \
# 0      \N             95            \N             [\N]           \N
# 1      \N             60   Documentary    [Documentary]  Documentary
# 2      \N             21         Short          [Short]        Short
# 3      \N            102  Drama,Family  [Drama, Family]        Drama
# 4      \N            102  Drama,Family  [Drama, Family]       Family
#
#          genre
# 0           \N
# 1  Documentary
# 2        Short
# 3        Drama
# 4        Drama

# %%
w = Window.partitionBy('genre').orderBy('startYear')
(
    df_titles_subset
    .withColumn('genre', f.split('genres', ',').getItem(0))
    .withColumn('startYear', f.col('startYear').cast('int'))
    .filter('startYear >= 2018 and genres_unico == "Comedy"')
    .withColumn('rn', f.percent_rank().over(w))
    .limit(25)
    .toPandas()
)
# Out:
#         tconst  averageRating  numVotes  titleType  \
# 0   tt10140580            7.4         5      short
# 1   tt10317978            6.8       146    tvMovie
# 2   tt10384130            4.2         5      movie
# 3   tt10683490            6.0         5  tvEpisode
# 4   tt10683538            5.8         5  tvEpisode
# 5   tt10683558            6.0         5  tvEpisode
# 6   tt10683582            6.0         5  tvEpisode
# 7   tt10683704            5.6         5  tvEpisode
# 8   tt10684910            5.8         5  tvEpisode
# 9   tt10709388            7.7        20      short
# 10  tt10793022            7.4         7  tvEpisode
# 11  tt10793026            6.4         5  tvEpisode
# 12  tt10793040            6.4         7  tvEpisode
# 13  tt10796382            6.0         5  tvEpisode
# 14  tt10796392            5.6         5  tvEpisode
# 15  tt10796402            5.8         5  tvEpisode
# 16  tt10796408            6.0         5  tvEpisode
# 17  tt10796412            6.2         5  tvEpisode
# 18  tt10803740            6.2         5  tvEpisode
# 19  tt10803744            5.8         5  tvEpisode
# 20  tt10803754            6.0         5  tvEpisode
# 21  tt10806466            6.4         5  tvEpisode
# 22  tt10806468            6.2         5  tvEpisode
# 23  tt10806476            6.6         5  tvEpisode
# 24  tt10806478            6.4         5  tvEpisode
#
#                                          primaryTitle  \
# 0                Draugurinn - A Ghostbusters fan film
# 1   Mob Psycho 100 REIGEN - The Miracle Psychic th...
# 2                                Fight Back to School
# 3                                    Change the World
# 4                                     It's Showtime!!
# 5                                           Be Honest
# 6                                      Shinovi Versus
# 7                                          Two Hearts
# 8                                            Hometown
# 9                       Anime: The Fast & The Furious
# 10      Library Hysteria" "Les vertiges de la lecture
# 11                                  Well Guarded Gold
# 12                                     Oggy en Egypte
# 13                           Désastre aux attractions
# 14                                   Panic in the Air
# 15                                           Zen Oggy
# 16                              Extreme Indoor Sports
# 17                                       Mouse Attack
# 18                                  The Power of Love
# 19                            Guess Who in the Fridge
# 20                                    Welcome to Mars
# 21                                      Brasse coulée
# 22                                      Coup de balai
# 23                                      A la poubelle
# 24                                 Tenor contre tenor
#
#                                         originalTitle isAdult  startYear  \
# 0                Draugurinn - A Ghostbusters fan film       0       2018
# 1   Mob Psycho 100 REIGEN - The Miracle Psychic th...       0       2018
# 2                                 Truong Hoc Ba Vuong       0       2018
# 3                                    Change the World       0       2018
# 4                                     It's Showtime!!       0       2018
# 5                                           Be Honest       0       2018
# 6                                      Shinovi Versus       0       2018
# 7                                          Two Hearts       0       2018
# 8                                            Hometown       0       2018
# 9                       Anime: The Fast & The Furious       0       2018
# 10      Library Hysteria" "Les vertiges de la lecture       0       2018
# 11                                  Well Guarded Gold       0       2018
# 12                                     Oggy en Egypte       0       2018
# 13                           Désastre aux attractions       0       2018
# 14                                   Panic in the Air       0       2018
# 15                                           Zen Oggy       0       2018
# 16                              Extreme Indoor Sports       0       2018
# 17                                       Mouse Attack       0       2018
# 18                                  The Power of Love       0       2018
# 19                            Guess Who in the Fridge       0       2018
# 20                                    Welcome to Mars       0       2018
# 21                                      Brasse coulée       0       2018
# 22                                      Coup de balai       0       2018
# 23                                      A la poubelle       0       2018
# 24                                 Tenor contre tenor       0       2018
#
#    endYear runtimeMinutes                   genres  \
# 0       \N              5      Action,Comedy,Short
# 1       \N             60  Action,Animation,Comedy
# 2       \N             99            Action,Comedy
# 3       \N             24  Action,Animation,Comedy
# 4       \N             24  Action,Animation,Comedy
# 5       \N             24  Action,Animation,Comedy
# 6       \N             24  Action,Animation,Comedy
# 7       \N             24  Action,Animation,Comedy
# 8       \N             24  Action,Animation,Comedy
# 9       \N              7      Action,Comedy,Short
# 10      \N             \N  Action,Animation,Comedy
# 11      \N             \N  Action,Animation,Comedy
# 12      \N             \N  Action,Animation,Comedy
# 13      \N             \N  Action,Animation,Comedy
# 14      \N             \N  Action,Animation,Comedy
# 15      \N             \N  Action,Animation,Comedy
# 16      \N             \N  Action,Animation,Comedy
# 17      \N             \N  Action,Animation,Comedy
# 18      \N             \N  Action,Animation,Comedy
# 19      \N             \N  Action,Animation,Comedy
# 20      \N             \N  Action,Animation,Comedy
# 21      \N             \N  Action,Animation,Comedy
# 22      \N             \N  Action,Animation,Comedy
# 23      \N             \N  Action,Animation,Comedy
# 24      \N             \N  Action,Animation,Comedy
#
#                    genres_array genres_unico   genre   rn
# 0       [Action, Comedy, Short]       Comedy  Action  0.0
# 1   [Action, Animation, Comedy]       Comedy  Action  0.0
# 2              [Action, Comedy]       Comedy  Action  0.0
# 3   [Action, Animation, Comedy]       Comedy  Action  0.0
# 4   [Action, Animation, Comedy]       Comedy  Action  0.0
# 5   [Action, Animation, Comedy]       Comedy  Action  0.0
# 6   [Action, Animation, Comedy]       Comedy  Action  0.0
# 7   [Action, Animation, Comedy]       Comedy  Action  0.0
# 8   [Action, Animation, Comedy]       Comedy  Action  0.0
# 9       [Action, Comedy, Short]       Comedy  Action  0.0
# 10  [Action, Animation, Comedy]       Comedy  Action  0.0
# 11  [Action, Animation, Comedy]       Comedy  Action  0.0
# 12  [Action, Animation, Comedy]       Comedy  Action  0.0
# 13  [Action, Animation, Comedy]       Comedy  Action  0.0
# 14  [Action, Animation, Comedy]       Comedy  Action  0.0
# 15  [Action, Animation, Comedy]       Comedy  Action  0.0
# 16  [Action, Animation, Comedy]       Comedy  Action  0.0
# 17  [Action, Animation, Comedy]       Comedy  Action  0.0
# 18  [Action, Animation, Comedy]       Comedy  Action  0.0
# 19  [Action, Animation, Comedy]       Comedy  Action  0.0
# 20  [Action, Animation, Comedy]       Comedy  Action  0.0
# 21  [Action, Animation, Comedy]       Comedy  Action  0.0
# 22  [Action, Animation, Comedy]       Comedy  Action  0.0
# 23  [Action, Animation, Comedy]       Comedy  Action  0.0
# 24  [Action, Animation, Comedy]       Comedy  Action  0.0

# %%
df_left.filter("startYear == '2018'").count()
# Out:
# 107080

# %%
df_left.filter("startYear == '2018' and genres_unico == 'Comedy'").count()
# Out:
# 16000
